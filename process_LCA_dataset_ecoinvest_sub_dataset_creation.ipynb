# %%
import pandas as pd

# %%
eco_invent_data=pd.read_excel("Database-Overview-for-ecoinvent-v3.9.1-9.xlsx",sheet_name=2)

# %%
eco_invent_data.head()
# Out:
#                         Activity UUID & Product UUID  \
# 0  dabb3812-eee9-5d2b-bc23-0f9a38e6f71e_bded6c5a-...
# 1  3b34f2a3-abfb-5681-ac78-60c8fada5b16_61c1d37e-...
# 2  3a2ab192-109a-5fa4-b9d9-7ed5421ce5c6_dfaef357-...
# 3  16e0e4f7-a44f-55d5-ae85-b2a614f42095_d5d05133-...
# 4  732c6740-c4fb-598d-89a0-f8d0a443913f_0d84cdfe-...
#
#                           Activity UUID  \
# 0  dabb3812-eee9-5d2b-bc23-0f9a38e6f71e
# 1  3b34f2a3-abfb-5681-ac78-60c8fada5b16
# 2  3a2ab192-109a-5fa4-b9d9-7ed5421ce5c6
# 3  16e0e4f7-a44f-55d5-ae85-b2a614f42095
# 4  732c6740-c4fb-598d-89a0-f8d0a443913f
#
#                                         EcoQuery URL  \
# 0  https://v391.ecoquery.ecoinvent.org/Details/UP...
# 1  https://v391.ecoquery.ecoinvent.org/Details/UP...
# 2  https://v391.ecoquery.ecoinvent.org/Details/UP...
# 3  https://v391.ecoquery.ecoinvent.org/Details/UP...
# 4  https://v391.ecoquery.ecoinvent.org/Details/UP...
#
# ...

# %%
eco_invent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21238 entries, 0 to 21237
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Activity UUID & Product UUID  21238 non-null  object
#  1   Activity UUID                 21238 non-null  object
#  2   EcoQuery URL                  21238 non-null  object
#  3   Activity Name                 21238 non-null  object
#  4   Geography                     21229 non-null  object
#  5   Time Period                   21238 non-null  object
#  6   Special Activity Type         21238 non-null  object
#  7   Sector                        21238 non-null  object
#  8   ISIC Classification           21238 non-null  object
#  9   ISIC Section                  21238 non-null  object
#  10  Product UUID                  21238 non-null  object
#  11  Reference Product Name        21238 non-null  object
# ...

# %%
eco_invent_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
eco_invent_data["Activity UUID"].duplicated().sum()
# Out:
# np.int64(2319)

# %%
eco_invent_data["Product Information"].duplicated().sum()
# Out:
# np.int64(17737)

# %%
eco_invent_data["Product UUID"].duplicated().sum()
# Out:
# np.int64(17688)

# %%
eco_invent_data["Activity UUID & Product UUID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
eco_invent_data[['Activity Name','Product Information']].duplicated().sum()
# Out:
# np.int64(11869)

# %%
eco_df = eco_invent_data.rename(
        columns={
            'Reference Product Name': 'reference_product',
            'Activity UUID & Product UUID': 'impact_factor_id',
            'Activity Name': 'impact_factor_name',
            'Product Information': 'product_info'
            }
        )

# %%
eco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21238 entries, 0 to 21237
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   impact_factor_id        21238 non-null  object
#  1   Activity UUID           21238 non-null  object
#  2   EcoQuery URL            21238 non-null  object
#  3   impact_factor_name      21238 non-null  object
#  4   Geography               21229 non-null  object
#  5   Time Period             21238 non-null  object
#  6   Special Activity Type   21238 non-null  object
#  7   Sector                  21238 non-null  object
#  8   ISIC Classification     21238 non-null  object
#  9   ISIC Section            21238 non-null  object
#  10  Product UUID            21238 non-null  object
#  11  reference_product       21238 non-null  object
#  12  CPC Classification      21238 non-null  object
#  13  Unit                    21238 non-null  object
# ...

# %%
req_eco=eco_df[['impact_factor_id','impact_factor_name','reference_product','product_info']]

# %%
req_eco.head(1)
# Out:
#                                     impact_factor_id  \
# 0  dabb3812-eee9-5d2b-bc23-0f9a38e6f71e_bded6c5a-...
#
#                                   impact_factor_name       reference_product  \
# 0  bark chips, wet, measured as dry mass to gener...  residual hardwood, wet
#
#                                         product_info
# 0  The product 'residual hardwood, wet' represent...

# %%
eco_df = eco_df.groupby('reference_product')
# eco_df.value_counts()

# %%
eco_df.get_group("1,1-difluoroethane, HFC-152a")
# Out:
#                                         impact_factor_id  \
# 9111   e3ef8fe3-f463-5a64-b0a4-8898873e1ba0_807906d0-...
# 13926  9358a211-ce2b-56d3-b2f2-db5ffce81e33_807906d0-...
# 15131  9b228f7c-b4a4-57bf-8adf-8c5638d5741a_807906d0-...
#
#                               Activity UUID  \
# 9111   e3ef8fe3-f463-5a64-b0a4-8898873e1ba0
# 13926  9358a211-ce2b-56d3-b2f2-db5ffce81e33
# 15131  9b228f7c-b4a4-57bf-8adf-8c5638d5741a
#
#                                             EcoQuery URL  \
# 9111   https://v391.ecoquery.ecoinvent.org/Details/UP...
# 13926  https://v391.ecoquery.ecoinvent.org/Details/UP...
# 15131  https://v391.ecoquery.ecoinvent.org/Details/UP...
#
#                             impact_factor_name Geography  Time Period  \
# 9111   market for 1,1-difluoroethane, HFC-152a       GLO  2011 - 2022
# 13926  1,1-difluoroethane production, HFC-152a       RoW  2005 - 2022
# 15131  1,1-difluoroethane production, HFC-152a        US  2005 - 2022
#
# ...

# %%
eco_df=eco_df.first().reset_index()

# %%
eco_df["reference_product"][0]
# Out:
# '1,1-difluoroethane, HFC-152a'

# %%
eco_df.to_csv("eco_invest_data_for_embedding.csv",index=False)
